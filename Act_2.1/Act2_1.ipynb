# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import glob

# %%
#pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %%
df = pd.read_csv("Athenas_Grecia_Dt.csv")
df.head()
# Out:
#    Unnamed: 0      id last_scraped       source  host_id  host_response_time  \
# 0           0   27262   2024-12-25  city scrape    37177      within an hour
# 1           1  809874   2024-12-25  city scrape  4259738      within an hour
# 2           2  866381   2024-12-25  city scrape  4551671  within a few hours
# 3           3  886724   2024-12-25  city scrape  4700824                 NaN
# 4           4  896212   2024-12-25  city scrape  4777984      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                 100%                 t
# 1               100%                  96%                 f
# 2               100%                  97%                 t
# 3                NaN                   0%                 f
# 4                95%                 100%                 t
#
#    host_listings_count  ...  review_scores_checkin  \
# 0                    4  ...                   4.86
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14642 entries, 0 to 14641
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    14642 non-null  int64
#  1   id                                            14642 non-null  int64
#  2   last_scraped                                  14642 non-null  object
#  3   source                                        14642 non-null  object
#  4   host_id                                       14642 non-null  int64
#  5   host_response_time                            12903 non-null  object
#  6   host_response_rate                            12903 non-null  object
#  7   host_acceptance_rate                          13811 non-null  object
#  8   host_is_superhost                             13868 non-null  object
# ...

# %%
#En vez de Nombre es  el de los 5 host_ID
filtro1=df[(df["host_id"]== 37177 ) | (df["host_id"]== 4259738 ) | (df["host_id"]== 4551671 ) | (df["host_id"]== 4700824 ) | (df["host_id"]== 4777984) ]

filtro1.to_csv("Filtro1.csv")
filtro1
# Out:
#        Unnamed: 0                   id last_scraped           source  host_id  \
# 0               0                27262   2024-12-25      city scrape    37177
# 1               1               809874   2024-12-25      city scrape  4259738
# 2               2               866381   2024-12-25      city scrape  4551671
# 3               3               886724   2024-12-25      city scrape  4700824
# 4               4               896212   2024-12-25      city scrape  4777984
# 5               5               905315   2024-12-25      city scrape  4777984
# 886           886             18250369   2024-12-25      city scrape  4777984
# 1207         1207             21650426   2024-12-25      city scrape  4777984
# 1233         1233             21057863   2024-12-26  previous scrape  4777984
# 2772         2772             33881866   2024-12-26  previous scrape  4777984
# 3627         3627             41072425   2024-12-25      city scrape  4777984
# ...

# %%
#Registros despues del año 2020
filtro2=df[df["last_scraped"] >= "2020-01-01"]

filtro2.to_csv("Filtro2.csv")
filtro2
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                27262   2024-12-25  city scrape      37177
# 1               1               809874   2024-12-25  city scrape    4259738
# 2               2               866381   2024-12-25  city scrape    4551671
# 3               3               886724   2024-12-25  city scrape    4700824
# 4               4               896212   2024-12-25  city scrape    4777984
# ...           ...                  ...          ...          ...        ...
# 14637       14637  1318251942056598277   2024-12-26  city scrape   25811452
# 14638       14638  1318276742106864141   2024-12-25  city scrape  666320836
# 14639       14639  1318307768558324736   2024-12-25  city scrape  221534605
# 14640       14640  1318405788507138933   2024-12-25  city scrape  650411545
# 14641       14641  1318601800941001079   2024-12-25  city scrape   31290848
#
# ...

# %%
#Analizar categorias de una columna
cat_hrt = df.groupby(['host_response_time'])['host_response_time'].count()
cat_hrt
# Out:
# host_response_time
# a few days or more      142
# within a day            393
# within a few hours      778
# within an hour        11590
# Name: host_response_time, dtype: int64

# %%
filtro3=df[(df["host_response_time"] == "within a day") | (df["host_response_time"] == "within a few hours") | (df["host_response_time"] == "within an hour")]

filtro3.to_csv("Filtro3.csv")
filtro3
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                27262   2024-12-25  city scrape      37177
# 1               1               809874   2024-12-25  city scrape    4259738
# 2               2               866381   2024-12-25  city scrape    4551671
# 4               4               896212   2024-12-25  city scrape    4777984
# 5               5               905315   2024-12-25  city scrape    4777984
# ...           ...                  ...          ...          ...        ...
# 14636       14636  1318247811815176103   2024-12-25  city scrape    7478461
# 14637       14637  1318251942056598277   2024-12-26  city scrape   25811452
# 14638       14638  1318276742106864141   2024-12-25  city scrape  666320836
# 14639       14639  1318307768558324736   2024-12-25  city scrape  221534605
# 14641       14641  1318601800941001079   2024-12-25  city scrape   31290848
#
# ...

# %%
#Multiplos de 200 
filtro4 = df.iloc[[200,400,600,800,1000,1200,1400,1600,1800,2000,2200,
                  2400,2600,2800,3000,3200,3400,3600,3800,4000,4200,4400,
                  4600,4800,5000,5200,5400,5600,5800,6000,6200,6400,6600,6800,
                  7000,7200,7400,7600,7800,8000,8200,8400,8600,8800,9000,
                  9200,9400,9600,9800], : ] #columnas en multiplo 

filtro4.to_csv("Filtro4.csv")
filtro4
# Out:
#       Unnamed: 0                   id last_scraped           source  \
# 200          200              2973483   2024-12-25      city scrape
# 400          400             11312612   2024-12-25      city scrape
# 600          600             13621619   2024-12-25      city scrape
# 800          800             17281679   2024-12-25      city scrape
# 1000        1000             19613468   2024-12-25      city scrape
# 1200        1200             20938041   2024-12-25      city scrape
# 1400        1400             23194228   2024-12-25      city scrape
# 1600        1600             24487266   2024-12-25      city scrape
# 1800        1800             26299378   2024-12-25      city scrape
# 2000        2000             27246550   2024-12-26      city scrape
# 2200        2200             29701261   2024-12-25      city scrape
# 2400        2400             31139423   2024-12-25      city scrape
# 2600        2600             32841822   2024-12-25      city scrape
# ...

# %%
#Los tipos de cuarto enteros y privados 
filtro5=df[(df["room_type"] == "Entire home/apt") | (df["room_type"] == "Private room")]

filtro5.to_csv("Filtro5.csv")
filtro5
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                27262   2024-12-25  city scrape      37177
# 1               1               809874   2024-12-25  city scrape    4259738
# 2               2               866381   2024-12-25  city scrape    4551671
# 3               3               886724   2024-12-25  city scrape    4700824
# 4               4               896212   2024-12-25  city scrape    4777984
# ...           ...                  ...          ...          ...        ...
# 14637       14637  1318251942056598277   2024-12-26  city scrape   25811452
# 14638       14638  1318276742106864141   2024-12-25  city scrape  666320836
# 14639       14639  1318307768558324736   2024-12-25  city scrape  221534605
# 14640       14640  1318405788507138933   2024-12-25  city scrape  650411545
# 14641       14641  1318601800941001079   2024-12-25  city scrape   31290848
#
# ...

# %%
#Los registros que a lo mucho tengan 4 camas
filtro6=df[(df["beds"] == 1) | (df["beds"] == 2) | (df["beds"] == 3) | (df["beds"] == 4)]

filtro6.to_csv("Filtro6.csv")
filtro6
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                27262   2024-12-25  city scrape      37177
# 1               1               809874   2024-12-25  city scrape    4259738
# 2               2               866381   2024-12-25  city scrape    4551671
# 3               3               886724   2024-12-25  city scrape    4700824
# 4               4               896212   2024-12-25  city scrape    4777984
# ...           ...                  ...          ...          ...        ...
# 14637       14637  1318251942056598277   2024-12-26  city scrape   25811452
# 14638       14638  1318276742106864141   2024-12-25  city scrape  666320836
# 14639       14639  1318307768558324736   2024-12-25  city scrape  221534605
# 14640       14640  1318405788507138933   2024-12-25  city scrape  650411545
# 14641       14641  1318601800941001079   2024-12-25  city scrape   31290848
#
# ...

# %%
#Los registros que sean superhosts
filtro7=df[df["host_is_superhost"] == "t"]

filtro7.to_csv("Filtro7.csv")
filtro7
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                27262   2024-12-25  city scrape      37177
# 2               2               866381   2024-12-25  city scrape    4551671
# 4               4               896212   2024-12-25  city scrape    4777984
# 5               5               905315   2024-12-25  city scrape    4777984
# 6               6               912425   2024-12-25  city scrape    4895605
# ...           ...                  ...          ...          ...        ...
# 14620       14620  1314986266535424845   2024-12-25  city scrape  194627760
# 14630       14630  1317984161119692105   2024-12-25  city scrape  509542156
# 14634       14634  1318190750706750006   2024-12-25  city scrape   23245295
# 14635       14635  1318194713882834447   2024-12-25  city scrape  400263201
# 14637       14637  1318251942056598277   2024-12-26  city scrape   25811452
#
# ...

# %%
#Los registros de las columnas impares
filtro8 =df.iloc [ :, 1::2] #columnas consecutivas  rango que yo quiera impar 


filtro8.to_csv("Filtro8.csv")
filtro8
# Out:
#                         id       source  host_response_time  \
# 0                    27262  city scrape      within an hour
# 1                   809874  city scrape      within an hour
# 2                   866381  city scrape  within a few hours
# 3                   886724  city scrape                 NaN
# 4                   896212  city scrape      within an hour
# ...                    ...          ...                 ...
# 14637  1318251942056598277  city scrape      within an hour
# 14638  1318276742106864141  city scrape  within a few hours
# 14639  1318307768558324736  city scrape  within a few hours
# 14640  1318405788507138933  city scrape                 NaN
# 14641  1318601800941001079  city scrape      within an hour
#
#       host_acceptance_rate  host_listings_count  \
# 0                     100%                    4
# 1                      96%                    2
# 2                      97%                    1
# ...
